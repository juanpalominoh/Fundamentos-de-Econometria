# 4503   8887      78982504 7.892   9.092  82.67
# 4504  58241    3391990528 9.698  10.972 120.39
# 4505  22116     489098368 9.098  10.004 100.08
# 4506  77682    6034451968 8.950  11.260 126.80
# 4507  43277    1872897664 9.173  10.675 113.96
# 4508  27332     747061056 8.878  10.216 104.36
# 4509  41732    1741537280 8.575  10.639 113.19
# 4510  12743     162375344 8.094   9.453  89.35
# 4511  31509     992798272 9.027  10.358 107.29
# 4512  32221    1038176448 8.601  10.380 107.75
# 4513  40292    1623415040 8.738  10.604 112.44
# 4514  60818    3698829568 9.700  11.016 121.34

# %%
names(base)
# Out:
#  [1] "conglome"   "vivienda"   "hogar"      "dpto"       "urbano"
#  [6] "costa"      "sierra"     "lima"       "mieperho"   "galimentos"
# [11] "ingresos"   "ing2"       "lnalim"     "lning"      "lning2"

# %%
options(prompt="R> ", digits=4, scipen=999)

# %% [markdown]
# # 1. Modelo MCO

# %%
formula <- lnalim ~ lning + mieperho + urbano + costa + sierra

# %%
ols <- lm(formula, data = base)
summary(ols)
# Out:
# Call:
# lm(formula = formula, data = base)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -9.381 -0.222  0.139  0.432  1.984
#
# Coefficients:
#             Estimate Std. Error t value            Pr(>|t|)
# (Intercept)  3.99550    0.20114   19.86 <0.0000000000000002 ***
# lning        0.37223    0.01925   19.33 <0.0000000000000002 ***
# mieperho     0.17711    0.00748   23.68 <0.0000000000000002 ***
# urbano       0.16220    0.05502    2.95              0.0032 **
# costa       -0.01235    0.03348   -0.37              0.7122
# sierra      -0.16440    0.06574   -2.50              0.0124 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.871 on 4508 degrees of freedom
# Multiple R-squared:  0.282,	Adjusted R-squared:  0.281
# F-statistic:  354 on 5 and 4508 DF,  p-value: <0.0000000000000002

# %% [markdown]
# # 2. Pruebas de Heterocedasticidad

# %%
install.packages("stargazer")
library("stargazer")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
#
# Please cite as:
#
#
#  Hlavac, Marek (2022). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#
#  R package version 5.2.3. https://CRAN.R-project.org/package=stargazer

# %% [markdown]
# ## 2.1. Test White (1era Forma)

# %%
# a. Capturo los residuos
resids <-ols$residuals
data_frame_white<-as.data.frame(cbind(base, resids))

# %%
# b. Regresion auxiliar
formula2 <- I(resids^2) ~ lning + mieperho + urbano + costa + sierra +
                  I(lning^2) + (lning*mieperho) + (lning*urbano) + (lning*costa) + (lning*sierra) +
                  I(mieperho^2) + (mieperho*urbano)+(mieperho*costa)+(mieperho*sierra)+
                  (urbano*costa)
  
regresion_auxiliar <- lm(formula2, data = data_frame_white)
sumario<- summary(regresion_auxiliar)
sumario
# Out:
# Call:
# lm(formula = formula2, data = data_frame_white)
#
# Residuals:
#    Min     1Q Median     3Q    Max
#  -6.77  -0.76  -0.30  -0.01  87.97
#
# Coefficients:
#                  Estimate Std. Error t value  Pr(>|t|)
# (Intercept)      54.92440   11.97631    4.59 0.0000046 ***
# lning           -10.12184    2.20687   -4.59 0.0000046 ***
# mieperho         -0.51260    0.71202   -0.72    0.4716
# urbano           10.55387    4.78113    2.21    0.0273 *
# costa            -6.70059    3.29756   -2.03    0.0422 *
# sierra          -17.30859    5.76348   -3.00    0.0027 **
# I(lning^2)        0.50977    0.10616    4.80 0.0000016 ***
# I(mieperho^2)     0.04113    0.01296    3.17    0.0015 **
# lning:mieperho   -0.02314    0.06991   -0.33    0.7406
# lning:urbano     -1.31952    0.49961   -2.64    0.0083 **
# lning:costa       0.45208    0.33159    1.36    0.1728
# lning:sierra      1.67223    0.59787    2.80    0.0052 **
# mieperho:urbano   0.31760    0.19152    1.66    0.0973 .
# mieperho:costa   -0.00946    0.11255   -0.08    0.9330
# mieperho:sierra  -0.18022    0.22529   -0.80    0.4238
# urbano:costa      1.67447    0.75249    2.23    0.0261 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 5.03 on 4498 degrees of freedom
# Multiple R-squared:  0.0239,	Adjusted R-squared:  0.0207
# F-statistic: 7.35 on 15 and 4498 DF,  p-value: 0.000000000000000243

# %%
# c. Validar la hipótesis nula
n <- nrow(data_frame_white)
R_2<- sumario$r.squared
LM_W<- n*R_2
gl <- 15        # Numero de variables explicativas de la ecuación auxiliar
p_value<- 1- pchisq(q = LM_W, df = gl)
VC<- qchisq(p = 0.95, df = gl)
salida_white<- c(LM_W, VC, p_value)
names(salida_white)<-c("LMw", "Valor critico", "p-value")
stargazer(salida_white, title = "Resultados de la prueba de white", type = "text", digits =0)
# Out:
# Resultados de la prueba de white
# =========================
# LMw Valor critico p-value
# -------------------------
# 108      25          0
# -------------------------

# %% [markdown]
# ## 2.2. Test White (2da forma)

# %%
install.packages("lmtest")
library(lmtest)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘zoo’
#
#
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric

# %%
prueba_white <- bptest(ols, 
                      ~ lning + mieperho + urbano + costa + sierra +
                        I(lning^2) + (lning*mieperho) + (lning*urbano) + (lning*costa) + (lning*sierra) +
                        I(mieperho^2) + (mieperho*urbano)+(mieperho*costa)+(mieperho*sierra)+
                        (urbano*costa),
                        data = base)
print(prueba_white)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  ols
# BP = 108, df = 15, p-value = 0.0000000000000004

# %% [markdown]
# ## 2.3. Test Breusch-Pagan/Godfrey

# %%
bpg <- bptest(formula, studentize = F, data=base)
bpg
# Out:
# 	Breusch-Pagan test
#
# data:  formula
# BP = 887, df = 5, p-value <0.0000000000000002

# %% [markdown]
# # 3. Modelo WLS

# %%
ols <- lm(formula, data = base)
summary(ols)
# Out:
# Call:
# lm(formula = formula, data = base)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -9.381 -0.222  0.139  0.432  1.984
#
# Coefficients:
#             Estimate Std. Error t value            Pr(>|t|)
# (Intercept)  3.99550    0.20114   19.86 <0.0000000000000002 ***
# lning        0.37223    0.01925   19.33 <0.0000000000000002 ***
# mieperho     0.17711    0.00748   23.68 <0.0000000000000002 ***
# urbano       0.16220    0.05502    2.95              0.0032 **
# costa       -0.01235    0.03348   -0.37              0.7122
# sierra      -0.16440    0.06574   -2.50              0.0124 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.871 on 4508 degrees of freedom
# Multiple R-squared:  0.282,	Adjusted R-squared:  0.281
# F-statistic:  354 on 5 and 4508 DF,  p-value: <0.0000000000000002

# %%
confint(ols, level=0.95)
resids  <- ols$residuals
resids2 <- resids^2
# Out:
#             2.5 %    97.5 %
# (Intercept)  3.60116  4.38983
# lning        0.33449  0.40998
# mieperho     0.16245  0.19177
# urbano       0.05433  0.27006
# costa       -0.07799  0.05329
# sierra      -0.29328 -0.03553

# %%
wls <- lm(formula, data = base, weights=(1/resids2))
summary(wls)
# Out:
# Call:
# lm(formula = formula, data = base, weights = (1/resids2))
#
# Weighted Residuals:
#    Min     1Q Median     3Q    Max
# -1.735 -1.000  0.994  0.999  1.718
#
# Coefficients:
#              Estimate Std. Error t value            Pr(>|t|)
# (Intercept)  4.003303   0.003930  1018.6 <0.0000000000000002 ***
# lning        0.372019   0.000239  1554.8 <0.0000000000000002 ***
# mieperho     0.176950   0.000111  1594.6 <0.0000000000000002 ***
# urbano       0.157640   0.002536    62.2 <0.0000000000000002 ***
# costa       -0.011929   0.000439   -27.2 <0.0000000000000002 ***
# sierra      -0.166501   0.003295   -50.5 <0.0000000000000002 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1 on 4508 degrees of freedom
# Multiple R-squared:  0.999,	Adjusted R-squared:  0.999
# F-statistic: 7.37e+05 on 5 and 4508 DF,  p-value: <0.0000000000000002

# %%
confint(wls, level=0.95)
# Out:
#             2.5 %    97.5 %
# (Intercept)  3.99560  4.01101
# lning        0.37155  0.37249
# mieperho     0.17673  0.17717
# urbano       0.15267  0.16261
# costa       -0.01279 -0.01107
# sierra      -0.17296 -0.16004

# %%
ci_ols <- confint(ols, level=0.95)
ci_wls <- confint(wls, level=0.95)
ci_ols
ci_wls
ci_ols[,2] - ci_ols[,1]
ci_wls[,2] - ci_wls[,1]
# Los intervalos de confianza de WLS son más estrechos o pequeños que los de OLS
# Por lo tanto, de acuerdo a la teoría, FGLS con un modelo corregido
# por heterocedasticidad es más eficiente que OLS
# Out:
#             2.5 %    97.5 %
# (Intercept)  3.60116  4.38983
# lning        0.33449  0.40998
# mieperho     0.16245  0.19177
# urbano       0.05433  0.27006
# costa       -0.07799  0.05329
# sierra      -0.29328 -0.03553
#             2.5 %    97.5 %
# (Intercept)  3.99560  4.01101
# lning        0.37155  0.37249
# mieperho     0.17673  0.17717
# urbano       0.15267  0.16261
# costa       -0.01279 -0.01107
# sierra      -0.17296 -0.16004
# (Intercept)       lning    mieperho      urbano       costa      sierra
#     0.78866     0.07549     0.02932     0.21573     0.13128     0.25775
# (Intercept)       lning    mieperho      urbano       costa      sierra
#   0.0154104   0.0009382   0.0004351   0.0099419   0.0017200   0.0129211

# %% [markdown]
# # 4. Modelo con errores estándar White

# %%
install.packages("sandwich")
library("sandwich")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
coeftest(ols, vcov=vcovHC(ols, "HC1"))
# Out:
# t test of coefficients:
#
#             Estimate Std. Error t value            Pr(>|t|)
# (Intercept)  3.99550    0.26423   15.12 <0.0000000000000002 ***
# lning        0.37223    0.02571   14.48 <0.0000000000000002 ***
# mieperho     0.17711    0.00856   20.70 <0.0000000000000002 ***
# urbano       0.16220    0.05425    2.99              0.0028 **
# costa       -0.01235    0.03267   -0.38              0.7054
# sierra      -0.16440    0.06897   -2.38              0.0172 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
